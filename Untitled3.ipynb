# %% [markdown]
# <a href="https://colab.research.google.com/github/maedapucho/Dokugaku-Prog/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# http://tinyurl.com/zcdx3yo.

# %%
print\
("""これは、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、
とても、とても、とても、とても、長い複数行のコードです""")
# Out:
# これは、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、とても、
# とても、とても、とても、とても、長い複数行のコードです
